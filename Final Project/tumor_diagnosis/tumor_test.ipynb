# %%
#load in tumor folder data
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')
# Set the path to the tumor folder
tumor_folder_path = 'path_to_tumor_folder'  # Replace with your actual
# Load the data from the tumor folder
tumor_data = pd.read_csv(os.path.join(tumor_folder_path, 'tumor_data.csv'))  # Replace with your actual file name
# Display the first few rows of the
print(tumor_data.head())
